# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    # "journal":{
    #     "file": "proceedings.bib",
    #     "venuekey" : "journal",
    #     "venue-pretext" : "",
    #     "collection" : {"name":"publications",
    #                     "permalink":"/publication/"}
    # },
    "pre-print":{
        "file": "pre-prints.bib",
        "venuekey" : "number",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED cao_etal_2021_knowledgeable_or_educated_guess?_revisiting_language_models_as_knowledge_bases: " Knowledgeable or {{Educated Guess}}? {{Revisiting Language M ... "
# SUCESSFULLY PARSED fangchao_etal_2021_from_learning-to-match_to_learning-to-discriminate:global_prototype_learning_for_few-shot_relation_classification: " From {{Learning-to-Match}} to {{Learning-to-Discriminate}}:{ ... "
# WARNING Missing Expected Field 'booktitle' from entry jiang_etal_2024_the_real_the_better:_aligning_large_language_models_with_online_human_behaviors: " The {{Real}}, the {{Better}}:  ... "
# SUCESSFULLY PARSED liu_etal_2021_element_intervention_for_open_relation_extraction: " Element {{Intervention}} for {{Open Relation Extraction}}  "
# WARNING Missing Expected Field 'booktitle' from entry lyu_etal_2024_knowtuning:_knowledge-aware_fine-tuning_for_large_language_models: " {{KnowTuning}}: {{Knowledge-aw ... "
# SUCESSFULLY PARSED NEURIPS2023_91228b94: " Learning to Tokenize for Generative Retrieval  "
# WARNING Missing Expected Field 'booktitle' from entry shi_etal_2024_chain_of_tools:_large_language_model_is_an_automatic_multi-tool_learner: " Chain of {{Tools}}: {{Large La ... "
# WARNING Missing Expected Field 'booktitle' from entry shi_etal_2024_learning_to_use_tools_via_cooperative_and_interactive_agents: " Learning to {{Use Tools}} via  ... "
# WARNING Missing Expected Field 'booktitle' from entry sun_etal_2023_instruction_distillation_makes_large_language_models_efficient_zero-shot_rankers: " Instruction {{Distillation Mak ... "
# SUCESSFULLY PARSED sun_etal_2023_is_chatgpt_good_at_search?_investigating_large_language_models_as_re-ranking_agents: " Is {{ChatGPT Good}} at {{Search}}? {{Investigating Large Lan ... "
# SUCESSFULLY PARSED yan_etal_2019_learning_to_bootstrap_for_entity_set_expansion: " Learning to {{Bootstrap}} for {{Entity Set Expansion}}  "
# SUCESSFULLY PARSED yan_etal_2020_end-to-end_bootstrapping_neural_network_for_entity_set_expansion: " End-to-{{End Bootstrapping Neural Network}} for {{Entity Set ... "
# WARNING Missing Expected Field 'booktitle' from entry yan_etal_2020_from_bag_of_sentences_to_document:_distantly_supervised_relation_extraction_via_machine_reading_comprehension: " From {{Bag}} of {{Sentences}}  ... "
# SUCESSFULLY PARSED yan_etal_2020_global_bootstrapping_neural_network_for_entity_set_expansion: " Global {{Bootstrapping Neural Network}} for {{Entity Set Exp ... "
# SUCESSFULLY PARSED yan_etal_2021_progressive_adversarial_learning_for_bootstrapping:_a_case_study_on_entity_set_expansion: " Progressive {{Adversarial Learning}} for {{Bootstrapping}}:  ... "
# SUCESSFULLY PARSED yan_etal_2021_reinforcement_learning_for_clue_selection_in_web-based_entity_translation_mining: " Reinforcement {{Learning}} for {{Clue Selection}} in {{Web-B ... "
# SUCESSFULLY PARSED zhao_etal_2023_diqad:_a_benchmark_dataset_for_open-domain_dialogue_quality_assessment: " {{DiQAD}}: {{A Benchmark Dataset}} for {{Open-domain Dialogu ... "
# SUCESSFULLY PARSED zhao_etal_2024_improving_the_robustness_of_large_language_models_via_consistency_alignment: " Improving the {{Robustness}} of {{Large Language Models}} vi ... "
# SUCESSFULLY PARSED zhao_etal_2024_knowing_what_llms_do_not_know:_a_simple_yet_effective_self-detection_method: " Knowing {{What LLMs DO NOT Know}}: {{A Simple Yet Effective  ... "
# WARNING Missing Expected Field 'booktitle' from entry zhu_etal_2024_atm:_adversarial_tuning_multi-agent_system_makes_a_robust_retrieval-augmented_generator: " {{ATM}}: {{Adversarial Tuning  ... "
# WARNING Missing Expected Field 'journal' from entry cao_etal_2021_knowledgeable_or_educated_guess?_revisiting_language_models_as_knowledge_bases: " Knowledgeable or {{Educated Gu ... "
# WARNING Missing Expected Field 'journal' from entry fangchao_etal_2021_from_learning-to-match_to_learning-to-discriminate:global_prototype_learning_for_few-shot_relation_classification: " From {{Learning-to-Match}} to  ... "
# WARNING Missing Expected Field 'journal' from entry jiang_etal_2024_the_real_the_better:_aligning_large_language_models_with_online_human_behaviors: " The {{Real}}, the {{Better}}:  ... "
# WARNING Missing Expected Field 'journal' from entry liu_etal_2021_element_intervention_for_open_relation_extraction: " Element {{Intervention}} for { ... "
# WARNING Missing Expected Field 'journal' from entry lyu_etal_2024_knowtuning:_knowledge-aware_fine-tuning_for_large_language_models: " {{KnowTuning}}: {{Knowledge-aw ... "
# WARNING Missing Expected Field 'journal' from entry NEURIPS2023_91228b94: " Learning to Tokenize for Gener ... "
# WARNING Missing Expected Field 'journal' from entry shi_etal_2024_chain_of_tools:_large_language_model_is_an_automatic_multi-tool_learner: " Chain of {{Tools}}: {{Large La ... "
# WARNING Missing Expected Field 'journal' from entry shi_etal_2024_learning_to_use_tools_via_cooperative_and_interactive_agents: " Learning to {{Use Tools}} via  ... "
# WARNING Missing Expected Field 'journal' from entry sun_etal_2023_instruction_distillation_makes_large_language_models_efficient_zero-shot_rankers: " Instruction {{Distillation Mak ... "
# WARNING Missing Expected Field 'journal' from entry sun_etal_2023_is_chatgpt_good_at_search?_investigating_large_language_models_as_re-ranking_agents: " Is {{ChatGPT Good}} at {{Searc ... "
# WARNING Missing Expected Field 'journal' from entry yan_etal_2019_learning_to_bootstrap_for_entity_set_expansion: " Learning to {{Bootstrap}} for  ... "
# WARNING Missing Expected Field 'journal' from entry yan_etal_2020_end-to-end_bootstrapping_neural_network_for_entity_set_expansion: " End-to-{{End Bootstrapping Neu ... "
# WARNING Missing Expected Field 'journal' from entry yan_etal_2020_from_bag_of_sentences_to_document:_distantly_supervised_relation_extraction_via_machine_reading_comprehension: " From {{Bag}} of {{Sentences}}  ... "
# WARNING Missing Expected Field 'journal' from entry yan_etal_2020_global_bootstrapping_neural_network_for_entity_set_expansion: " Global {{Bootstrapping Neural  ... "
# WARNING Missing Expected Field 'journal' from entry yan_etal_2021_progressive_adversarial_learning_for_bootstrapping:_a_case_study_on_entity_set_expansion: " Progressive {{Adversarial Lear ... "
# WARNING Missing Expected Field 'journal' from entry yan_etal_2021_reinforcement_learning_for_clue_selection_in_web-based_entity_translation_mining: " Reinforcement {{Learning}} for ... "
# WARNING Missing Expected Field 'journal' from entry zhao_etal_2023_diqad:_a_benchmark_dataset_for_open-domain_dialogue_quality_assessment: " {{DiQAD}}: {{A Benchmark Datas ... "
# WARNING Missing Expected Field 'journal' from entry zhao_etal_2024_improving_the_robustness_of_large_language_models_via_consistency_alignment: " Improving the {{Robustness}} o ... "
# WARNING Missing Expected Field 'journal' from entry zhao_etal_2024_knowing_what_llms_do_not_know:_a_simple_yet_effective_self-detection_method: " Knowing {{What LLMs DO NOT Kno ... "
# WARNING Missing Expected Field 'journal' from entry zhu_etal_2024_atm:_adversarial_tuning_multi-agent_system_makes_a_robust_retrieval-augmented_generator: " {{ATM}}: {{Adversarial Tuning  ... "
